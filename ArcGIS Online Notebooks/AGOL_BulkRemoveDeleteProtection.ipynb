# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# /opt/conda/lib/python3.11/site-packages/arcgis/gis/__init__.py:731: UserWarning: You are logged on as amanikas_lpta with an administrator role, proceed with caution.
#   warnings.warn(

# %% [markdown]
# #### Now you are ready to start!

# %%
gis.content.search('03261e4e8efc4e2cad8926699cd9a32a')[0].type
# Out:
# 'Service Definition'

# %%
serviceDefinitionArray = gis.content.search(query='', item_type='Service Definition', max_items=1000)
print(len(serviceDefinitionArray), "Service Definition Items Queried...")
# Out:
# 118 Service Definition Items Queried...

# %%
for sd in serviceDefinitionArray:
    sd.protect(enable=False)

# %%
shapefileArray = gis.content.search(query='', item_type='Shapefile', max_items=1000)
print(len(shapefileArray), "Shapefile Items Queried...")
# Out:
# 38 Shapefile Items Queried...
